# %% [markdown]
# ### Start importing all libraries

# %%
# Global
import numpy as np
import tqdm

# Local
import examples_utils as eu
import fastPTA.utils as ut
import fastPTA.plotting_functions as pf

from fastPTA.priors import Priors
from fastPTA.signals import get_signal_model
from fastPTA.Fisher_code import compute_fisher
from fastPTA.MCMC_code import run_MCMC

# %% [markdown]
# ### Constants to be used in the analysis

# %%
# Total observation time in years
T_obs_yrs = 10.0  # 6.03

# Number of frequencies used in the analysis
n_frequencies = 30

# Number of pulsars in the analysis
n_pulsars = 100

# Specify the type of noise to be used in the analysis
which_experiment = eu.mockSKA10

# Set the label to specify the signal model
signal_label = "power_law_SIGW"

# The analysis assumes a power law template, specify here the input parameters
log_amplitude = -7.1995  # log amplitude of the power law
tilt = 2.0  # Tilt of the power law
SIGW_log_amplitude = -2  # log amplitude SIGW
SIGW_log_width = np.log10(0.5)  # log width SIGW
SIGW_log_pivot = -8.45  # log pivot SIGW

# Specify the true signal parameters
signal_parameters = np.array(
    [log_amplitude, tilt, SIGW_log_amplitude, SIGW_log_width, SIGW_log_pivot]
)

# Specify the labels for the signal parameters
parameter_labels = []

# Specify the priors for the signal parameters (should be a dictionary, the
# parameter names are the keys and the values are the dictionaries with the
# prior information) if not specfied here will build from fisher results
priors_dictionary = {}

# Number of points to generate for the Fisher
len_fisher_data = int(1e4)

# Name of the pulsar catalogue
outname = "pulsar_configurations/SKA200p.txt"

# %% [markdown]
# ### Some inputs for the MCMC

# %%
# Whether the MCMC should be rerun
rerun_MCMC = True

# Whether the MCMC data should be regenerated
regenerate_MCMC_data = True

# Whether to generate a data realization or take data at face value
realization = False

# Number of burnin steps for the MCMC
burnin_steps_default = 100

# Maximum number of iterations to get R close to 1
i_max_default = 100

# Accepted value for the Gellman-Rubin convergence criterion
R_convergence_default = 1e-1

# Criterion to be used for the convergence of the MCMC chains
R_criterion_default = "mean_squared"

# Number of MCMC steps in each iteration
MCMC_iteration_steps_default = 300

# Path to the MCMC_data
path_to_MCMC_data = "generated_data/MCMC_data_Pl+SIGW_200p.npz"

# Path to the MCMC chains
path_to_MCMC_chains = "generated_chains/MCMC_chains_Pl+SIGW_200p.npz"

# %% [markdown]
# ### Set the inputs for the Fisher and MCMC analysis

# %%
# Get the signal model
signal_model = get_signal_model(signal_label)

# Dictionary with the kwargs to generete the pulsar catalogs
generate_catalog_kwargs = {
    "n_pulsars": n_pulsars,
    "save_catalog": True,
    **which_experiment,
}

# Dictionary with the kwargs to generate noise and orf tensors
get_tensors_kwargs = {
    "add_curn": False,
    "regenerate_catalog": True,
    "path_to_pulsar_catalog": outname,
}

# Dictionary with the kwargs for the Fisher matrix
fisher_kwargs = {
    "T_obs_yrs": T_obs_yrs,
    "n_frequencies": n_frequencies,
    "signal_model": signal_model,
    "signal_parameters": signal_parameters,
}

# Dictionary with the kwargs for the MCMC
MCMC_kwargs = {
    "regenerate_MCMC_data": regenerate_MCMC_data,
    "realization": realization,
    "path_to_MCMC_data": path_to_MCMC_data,
    "path_to_MCMC_chains": path_to_MCMC_chains,
    "i_max": i_max_default,
    "R_convergence": R_convergence_default,
    "R_criterion": R_criterion_default,
    "burnin_steps": burnin_steps_default,
    "MCMC_iteration_steps": MCMC_iteration_steps_default,
}

# %% [markdown]
# ### Prepare the model to scan over

# %%
if "regenerate_catalog" in get_tensors_kwargs.keys():
    if get_tensors_kwargs["regenerate_catalog"]:
        rerun_MCMC = True

(
    frequency,
    signal_value,
    HD_functions_IJ,
    HD_coeffs,
    effective_noise,
    SNR,
    fisher,
) = compute_fisher(
    **fisher_kwargs,
    get_tensors_kwargs=get_tensors_kwargs,
    generate_catalog_kwargs=generate_catalog_kwargs,
)

covariance = ut.compute_inverse(fisher)
fisher_data = np.random.multivariate_normal(
    signal_parameters, covariance, size=len_fisher_data
)
errors = np.sqrt(np.diag(covariance))
print("Fisher errors", errors)

fisher_ranges = np.vstack(
    (signal_parameters - 5 * errors, signal_parameters + 5 * errors)
)

get_tensors_kwargs["regenerate_catalog"] = False
# Out:
# Fisher errors [0.02205475 0.09323647 1.56807084 2.75769828 0.47715658]

# %%
to_keep = []

for i in tqdm.tqdm(range(len(fisher_data))):

    PBH_abundance = signal_model.get_PBH_abundance(fisher_data[i])

    if PBH_abundance > 1 or np.isnan(PBH_abundance):
        to_keep.append(False)

    else:
        to_keep.append(True)

fisher_reject = fisher_data[to_keep]
# Out:
# 100%|██████████| 10000/10000 [00:27<00:00, 360.83it/s]

# %%
mean = np.mean(fisher_reject, axis=0)
std = np.std(fisher_reject, axis=0)

# %%
parameter_names = signal_model.parameter_names

ndims = len(parameter_names)
nwalkers = max(2 * ndims, 5)
initial = np.empty((nwalkers, ndims))

mins = np.array([s * 0.95 if s > 0 else s * 1.05 for s in signal_parameters])
maxs = np.array([s * 1.05 if s > 0 else s * 0.95 for s in signal_parameters])

i = 0
while i < nwalkers:
    new = np.random.uniform(mins, maxs)
    
    PBH_abundance = signal_model.get_PBH_abundance(new)

    if PBH_abundance > 1 or np.isnan(PBH_abundance):
        pass  # Do nothing
    else:
        initial[i] = new
        i += 1

# %%
# If the priors dictionary is empty, build it from the Fisher results
if True:  # not priors_dictionary:

    mins = np.array([s * 0.9 if s > 0 else s * 1.1 for s in signal_parameters])
    maxs = np.array([s * 1.1 if s > 0 else s * 0.9 for s in signal_parameters])

    parameter_names = signal_model.parameter_names
    diffs = np.abs(np.diff(fisher_ranges, axis=0).squeeze())

    for i in range(len(parameter_names)):

        if i < 2:
            priors_dictionary[parameter_names[i]] = {
                "uniform": {"loc": fisher_ranges[0, i], "scale": diffs[i]}
            }

        else:
            priors_dictionary[parameter_names[i]] = {
                "uniform": {"loc": -10.0, "scale": 10.0}
            }

priors_dictionary["log_amplitude_scalar"] = {
    "uniform": {"loc": -4.0, "scale": 4.0}
}
priors_dictionary["log_width"] = {"uniform": {"loc": -3, "scale": 4}}
priors_dictionary["log_pivot"] = {"uniform": {"loc": -10.0, "scale": 3.}}

priors = Priors(
    priors_dictionary, get_PBH_abundance=signal_model.get_PBH_abundance, check_PBH_abundance=False,
)

# %%
print(priors.priors)
# Out:
# {'log_amplitude_PL': {'pdf': <bound method rv_continuous.pdf of <scipy.stats._continuous_distns.uniform_gen object at 0x7bfd1d1c7cd0>>, 'rvs': <bound method rv_generic.rvs of <scipy.stats._continuous_distns.uniform_gen object at 0x7bfd1d1c7cd0>>, 'pdf_kwargs': {'loc': np.float64(-7.309773770242445), 'scale': np.float64(0.22054754048489045)}}, 'tilt': {'pdf': <bound method rv_continuous.pdf of <scipy.stats._continuous_distns.uniform_gen object at 0x7bfd1d1c7cd0>>, 'rvs': <bound method rv_generic.rvs of <scipy.stats._continuous_distns.uniform_gen object at 0x7bfd1d1c7cd0>>, 'pdf_kwargs': {'loc': np.float64(1.5338176537865669), 'scale': np.float64(0.9323646924268665)}}, 'log_amplitude_scalar': {'pdf': <bound method rv_continuous.pdf of <scipy.stats._continuous_distns.uniform_gen object at 0x7bfd1d1c7cd0>>, 'rvs': <bound method rv_generic.rvs of <scipy.stats._continuous_distns.uniform_gen object at 0x7bfd1d1c7cd0>>, 'pdf_kwargs': {'loc': -4.0, 'scale': 4.0}}, 'log_width': {'pdf': <bound method rv_continuous.pdf of <scipy.stats._continuous_distns.uniform_gen object at 0x7bfd1d1c7cd0>>, 'rvs': <bound method rv_generic.rvs of <scipy.stats._continuous_distns.uniform_gen object at 0x7bfd1d1c7cd0>>, 'pdf_kwargs': {'loc': -3, 'scale': 4}}, 'log_pivot': {'pdf': <bound method rv_continuous.pdf of <scipy.stats._continuous_distns.uniform_gen object at 0x7bfd1d1c7cd0>>, 'rvs': <bound method rv_generic.rvs of <scipy.stats._continuous_distns.uniform_gen object at 0x7bfd1d1c7cd0>>, 'pdf_kwargs': {'loc': -10.0, 'scale': 3.0}}}

# %%
try:
    if rerun_MCMC:
        raise FileNotFoundError("Flag forces MCMC chains regeneration")

    MCMC_results = np.load(path_to_MCMC_chains)
    MCMC_data = MCMC_results["samples"]
    pdfs = MCMC_results["pdfs"]

except FileNotFoundError:
    MCMC_data, pdfs = run_MCMC(
        priors,
        initial=initial,
        **fisher_kwargs,
        **MCMC_kwargs,
        get_tensors_kwargs=get_tensors_kwargs,
    )
# Out:
# Regenerating MCMC data
# - Data will use the expectation value
#
# Initial run
#   0%|          | 0/100 [00:00<?, ?it/s]/home/pieroni/.pyenv/versions/3.11.9/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# 100%|██████████| 100/100 [00:46<00:00,  2.15it/s]
# Burn-in dropped, here starts the proper run
#  83%|████████▎ | 249/300 [02:00<00:24,  2.07it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 3
#       2 if rerun_MCMC:
# ----> 3     raise FileNotFoundError("Flag forces MCMC chains regeneration")
#       5 MCMC_results = np.load(path_to_MCMC_chains)
#
# FileNotFoundError: Flag forces MCMC chains regeneration
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 10
#       7     pdfs = MCMC_results["pdfs"]
#       9 except FileNotFoundError:
# ---> 10     MCMC_data, pdfs = run_MCMC(
#      11         priors,
#      12         initial=initial,
#      13         **fisher_kwargs,
#      14         **MCMC_kwargs,
#      15         get_tensors_kwargs=get_tensors_kwargs,
#      16     )
#
# File ~/Desktop/My_projects/PTA_chiara/fastpta_models/fastPTA/MCMC_code.py:512, in run_MCMC(priors, T_obs_yrs, n_frequencies, signal_model, signal_parameters, initial, regenerate_MCMC_data, realization, save_MCMC_data, path_to_MCMC_data, i_max, R_convergence, R_criterion, burnin_steps, MCMC_iteration_steps, path_to_MCMC_chains, get_tensors_kwargs, generate_catalog_kwargs)
#     509 # Run until convergence or until reached maximum number of iterations
#     510 while np.abs(R - 1) > R_convergence and i < i_max:
#     511     # Run this iteration
# --> 512     state = sampler.run_mcmc(state, MCMC_iteration_steps, progress=True)
#     514     # Get Gelman-Rubin at this step
#     515     R_array = ut.get_R(sampler.get_chain())
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/emcee/ensemble.py:450, in EnsembleSampler.run_mcmc(self, initial_state, nsteps, **kwargs)
#     447     initial_state = self._previous_state
#     449 results = None
# --> 450 for results in self.sample(initial_state, iterations=nsteps, **kwargs):
#     451     pass
#     453 # Store so that the ``initial_state=None`` case will work
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/emcee/ensemble.py:409, in EnsembleSampler.sample(self, initial_state, log_prob0, rstate0, blobs0, iterations, tune, skip_initial_state_check, thin_by, thin, store, progress, progress_kwargs)
#     406 move = self._random.choice(self._moves, p=self._weights)
#     408 # Propose
# --> 409 state, accepted = move.propose(model, state)
#     410 state.random_state = self.random_state
#     412 if tune:
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/emcee/moves/red_blue.py:93, in RedBlueMove.propose(self, model, state)
#      90 q, factors = self.get_proposal(s, c, model.random)
#      92 # Compute the lnprobs of the proposed position.
# ---> 93 new_log_probs, new_blobs = model.compute_log_prob_fn(q)
#      95 # Loop over the walkers and update them accordingly.
#      96 for i, (j, f, nlp) in enumerate(
#      97     zip(all_inds[S1], factors, new_log_probs)
#      98 ):
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/emcee/ensemble.py:551, in EnsembleSampler.compute_log_prob(self, coords)
#     549 # Check for log_prob returning NaN.
#     550 if np.any(np.isnan(log_prob)):
# --> 551     raise ValueError("Probability function returned NaN")
#     553 return log_prob, blob
#
# ValueError: Probability function returned NaN

# %%
debug
# Out:
# > /home/pieroni/.pyenv/versions/3.11.9/lib/python3.11/site-packages/emcee/ensemble.py(551)compute_log_prob()
#     549         # Check for log_prob returning NaN.
#     550         if np.any(np.isnan(log_prob)):
# --> 551             raise ValueError("Probability function returned NaN")
#     552
#     553         return log_prob, blob
#
# > /home/pieroni/.pyenv/versions/3.11.9/lib/python3.11/site-packages/emcee/moves/red_blue.py(93)propose()
#      91
#      92             # Compute the lnprobs of the proposed position.
# ---> 93             new_log_probs, new_blobs = model.compute_log_prob_fn(q)
#      94
#      95             # Loop over the walkers and update them accordingly.
#
# > /home/pieroni/.pyenv/versions/3.11.9/lib/python3.11/site-packages/emcee/ensemble.py(409)sample()
#     407
#     408                     # Propose
# --> 409                     state, accepted = move.propose(model, state)
#     410                     state.random_state = self.random_state
#     411
#
# > /home/pieroni/.pyenv/versions/3.11.9/lib/python3.11/site-packages/emcee/ensemble.py(450)run_mcmc()
#     448
#     449         results = None
# --> 450         for results in self.sample(initial_state, iterations=nsteps, **kwargs):
#     451             pass
#     452
#
# *** NameError: name 'state' is not defined
# > /home/pieroni/Desktop/My_projects/PTA_chiara/fastpta_models/fastPTA/MCMC_code.py(512)run_MCMC()
#     510     while np.abs(R - 1) > R_convergence and i < i_max:
#     511         # Run this iteration
# --> 512         state = sampler.run_mcmc(state, MCMC_iteration_steps, progress=True)
#     513
#     514         # Get Gelman-Rubin at this step
#
# > /tmp/ipykernel_65622/797928998.py(10)<module>()
#       8
#       9 except FileNotFoundError:
# ---> 10     MCMC_data, pdfs = run_MCMC(
#      11         priors,
#      12         initial=initial,
#
# *** NameError: name 'state' is not defined
# *** all frames above hidden, use `skip_hidden False` to get get into those.
# *** all frames above hidden, use `skip_hidden False` to get get into those.
# *** all frames above hidden, use `skip_hidden False` to get get into those.
# > /home/pieroni/Desktop/My_projects/PTA_chiara/fastpta_models/fastPTA/MCMC_code.py(512)run_MCMC()
#     510     while np.abs(R - 1) > R_convergence and i < i_max:
#     511         # Run this iteration
# --> 512         state = sampler.run_mcmc(state, MCMC_iteration_steps, progress=True)
#     513
#     514         # Get Gelman-Rubin at this step
#
# > /home/pieroni/.pyenv/versions/3.11.9/lib/python3.11/site-packages/emcee/ensemble.py(450)run_mcmc()
#     448
#     449         results = None
# --> 450         for results in self.sample(initial_state, iterations=nsteps, **kwargs):
#     451             pass
#     452
#
# > /home/pieroni/.pyenv/versions/3.11.9/lib/python3.11/site-packages/emcee/ensemble.py(409)sample()
#     407
#     408                     # Propose
# --> 409                     state, accepted = move.propose(model, state)
#     410                     state.random_state = self.random_state
#     411
#
# Model(log_prob_fn=<emcee.ensemble._FunctionWrapper object at 0x7bfca8e7df50>, compute_log_prob_fn=<bound method EnsembleSampler.compute_log_prob of <emcee.ensemble.EnsembleSampler object at 0x7bfc79e3b710>>, map_fn=<class 'map'>, random=RandomState(MT19937) at 0x7BFCA8D2C140)
# State([[-7.18945023  2.1090201  -0.93444613  0.78633635 -8.98422622]
#  [-7.21538987  2.01982969 -1.16069529 -0.17309981 -9.0802175 ]
#  [-7.18060276  2.06443053 -1.93717847 -0.29718735 -8.33008481]
#  [-7.19797252  1.88698457 -1.13111198  0.61241305 -9.23294849]
#  [-7.23547463  1.87726559 -1.61616168  0.09893984 -8.87544346]
#  [-7.24840278  2.44064315 -1.13711508  0.04405508 -7.42983803]
#  [-7.20358541  1.91588164 -1.84044422 -1.11278247 -8.63402287]
#  [-7.23349518  1.91890051 -2.10229634 -0.50926951 -8.44440276]
#        2662512434, 3070459250, 3761216425,  559947493, 3211470386,
#            253618, 2655221663,  375091768, 3522440307, 2883459486,
#          44548202,  666822762, 3089007422, 2019358821, 1798903137,
#        1199444350, 2289820754, 1055738635, 3174106935,  430161088,
#        1528767753, 3662720642, 3755145663, 3827722174,  216995733,
#        1343165467, 3875922193,  639065443, 2877731124, 3721907177,
#        1941891065, 2832957449, 1279378077,  503299631, 1736350535,
#        2877760460, 1339370956, 1556955434, 1473084353,  905570917,
#        1288472767, 1686674765, 1569037038, 2021640481, 2644371399,
#        1401808644, 1846703542, 2946103630,   12682271,  474690596,
#        2477135359, 3691766537,  317676212, 1469744105, 1018593140,
#        3224190673, 1943661413, 2762200324,  851218290, 3592650280,
#        1855973411, 1606882164, 3280263966,  269169688,  318669023,
#        1121700510, 3306506926, 1404527314, 1161628152,   91225791,
#        2294746398, 2155562434, 2737321770, 1932414528, 1148930599,
#        2409269915, 3458212302,  759497116, 1880202217, 1637699430,
#        4173850166, 4144313781, 1435959245, 2417476881, 1399829619,
#        2446299491, 1753667991,  147807380, 1393676620,  564746442,
#        3733007164, 2681380600, 1007481529, 1136957856,  392118537,
#        1948464435,   94281565,  370698939, 3028808178, 3904971041,
#        1059838745,   76175921,  403497124, 3696384097, 3674271384,
#        3290071643,  515457643, 2232430687, 4259781208, 1778826792,
#        1895712732, 1900602740, 2530129785, 3995533021, 1350895065,
#        3705874253, 4171802305, 1213443438, 2359691704, 2308080867,
#        2982247024, 1159034337, 3368014155,  213177454, 3294010712,
#        4147518001, 2302794919, 3947765605,  828363936], dtype=uint32), 516, 0, 0.0))
# > /home/pieroni/.pyenv/versions/3.11.9/lib/python3.11/site-packages/emcee/moves/red_blue.py(93)propose()
#      91
#      92             # Compute the lnprobs of the proposed position.
# ---> 93             new_log_probs, new_blobs = model.compute_log_prob_fn(q)
#      94
#      95             # Loop over the walkers and update them accordingly.
#
# > /home/pieroni/.pyenv/versions/3.11.9/lib/python3.11/site-packages/emcee/ensemble.py(409)sample()
#     407
#     408                     # Propose
# --> 409                     state, accepted = move.propose(model, state)
#     410                     state.random_state = self.random_state
#     411
#
# > /home/pieroni/.pyenv/versions/3.11.9/lib/python3.11/site-packages/emcee/ensemble.py(450)run_mcmc()
#     448
#     449         results = None
# --> 450         for results in self.sample(initial_state, iterations=nsteps, **kwargs):
#     451             pass
#     452
#
# > /home/pieroni/Desktop/My_projects/PTA_chiara/fastpta_models/fastPTA/MCMC_code.py(512)run_MCMC()
#     510     while np.abs(R - 1) > R_convergence and i < i_max:
#     511         # Run this iteration
# --> 512         state = sampler.run_mcmc(state, MCMC_iteration_steps, progress=True)
#     513
#     514         # Get Gelman-Rubin at this step
#
# State([[-7.2016805   1.92696405 -2.08245711 -0.29260533 -8.64002219]
#  [-7.21827014  1.96208644 -1.88800214 -0.34411007 -8.76280741]
#  [-7.20364309  2.01024457 -2.02785256 -0.29476977 -8.43639656]
#  [-7.19827599  1.89422232 -2.00379272 -0.39227193 -8.7817563 ]
#        2137023809, 4132048414, 3072557820, 3590791190, 1088670823,
#          60212001, 3046887998,  442435454, 4059739694, 1785768058,
#        4150521943,  217122092, 3300987383, 3136036678, 1517255994,
#        4084592503, 2186709112, 1009746783, 4142693321, 2220858694,
#         981891308,  334137629, 2843212566, 2562768237, 3059906095,
#        1889665206,  340279003, 1840118271, 2851489065, 1950675454,
#        3586334863,  339281758, 3721448371, 1410912456,  686628476,
#         594545538,  832223386, 3224880658, 1889740750,  396342477,
#        3031498136,  132785276,  472926131, 2532686325, 3107488372,
#        1959308373, 2668525740,  559430673, 3276134770, 4071495471,
#         204126404, 3666083263, 2474183085, 2715432309, 3890622200,
#        2662512434, 3070459250, 3761216425,  559947493, 3211470386,
#            253618, 2655221663,  375091768, 3522440307, 2883459486,
#          44548202,  666822762, 3089007422, 2019358821, 1798903137,
#        1199444350, 2289820754, 1055738635, 3174106935,  430161088,
#        1528767753, 3662720642, 3755145663, 3827722174,  216995733,
#        1343165467, 3875922193,  639065443, 2877731124, 3721907177,
#        1941891065, 2832957449, 1279378077,  503299631, 1736350535,
#        2877760460, 1339370956, 1556955434, 1473084353,  905570917,
#        1288472767, 1686674765, 1569037038, 2021640481, 2644371399,
#        1401808644, 1846703542, 2946103630,   12682271,  474690596,
#        2477135359, 3691766537,  317676212, 1469744105, 1018593140,
#        3224190673, 1943661413, 2762200324,  851218290, 3592650280,
#        1855973411, 1606882164, 3280263966,  269169688,  318669023,
#        1121700510, 3306506926, 1404527314, 1161628152,   91225791,
#        2294746398, 2155562434, 2737321770, 1932414528, 1148930599,
#        2409269915, 3458212302,  759497116, 1880202217, 1637699430,
#        4173850166, 4144313781, 1435959245, 2417476881, 1399829619,
#        2446299491, 1753667991,  147807380, 1393676620,  564746442,
#        3733007164, 2681380600, 1007481529, 1136957856,  392118537,
#        1948464435,   94281565,  370698939, 3028808178, 3904971041,
#        1059838745,   76175921,  403497124, 3696384097, 3674271384,
#        3290071643,  515457643, 2232430687, 4259781208, 1778826792,
#        1895712732, 1900602740, 2530129785, 3995533021, 1350895065,
#        3705874253, 4171802305, 1213443438, 2359691704, 2308080867,
#        2982247024, 1159034337, 3368014155,  213177454, 3294010712,
#        4147518001, 2302794919, 3947765605,  828363936], dtype=uint32), 516, 0, 0.0))
# 300

# %%
# Set the labels for the signal parameters
if not parameter_labels:
    parameter_labels = signal_model.parameter_labels

# Prepare input for the plotting function
datasets = [fisher_data, fisher_reject, MCMC_data]
weights = [
    np.ones(len_fisher_data),
    np.ones(len(fisher_reject)),
    np.ones(MCMC_data.shape[0]),  # type: ignore
]
smooth = [1.0, 1.0, 1.0]
ranges = np.array(fisher_ranges.T)
colors = [
    pf.my_colormap["red"],
    pf.my_colormap["blue"],
    pf.my_colormap["green"],
]

# Do the corner plot
pf.plot_corner(
    datasets,
    colors=colors,
    truths=signal_parameters,
    chain_labels=["Fisher", "Fisher reject", "MCMC"],
    weights=weights,
    smooth=smooth,
    labels=parameter_labels,
    # range=ranges,
    truth_color="black",
)
