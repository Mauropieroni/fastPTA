# %% [markdown]
# ### Start importing all libraries

# %%
# Global
import numpy as np
import tqdm

# Local
import examples_utils as eu
import fastPTA.utils as ut
import fastPTA.plotting_functions as pf

from fastPTA.priors import Priors
from fastPTA.signals import get_signal_model
from fastPTA.Fisher_code import compute_fisher
from fastPTA.MCMC_code import run_MCMC

# %% [markdown]
# ### Constants to be used in the analysis

# %%
# Total observation time in years
T_obs_yrs = 10.0  # 6.03

# Number of frequencies used in the analysis
n_frequencies = 30

# Number of pulsars in the analysis
n_pulsars = 200

# Specify the type of noise to be used in the analysis
which_experiment = eu.mockSKA10

# Set the label to specify the signal model
signal_label = "power_law_SIGW"

# The analysis assumes a power law template, specify here the input parameters
log_amplitude = -7.1995  # log amplitude of the power law
tilt = 2.0  # Tilt of the power law
SIGW_log_amplitude = -1.7  # log amplitude SIGW
SIGW_log_width = np.log10(0.5)  # log width SIGW
SIGW_log_pivot = -8.25  # log pivot SIGW

# Specify the true signal parameters
signal_parameters = np.array(
    [log_amplitude, tilt, SIGW_log_amplitude, SIGW_log_width, SIGW_log_pivot]
)

# Specify the labels for the signal parameters
parameter_labels = []

# Specify the priors for the signal parameters (should be a dictionary, the
# parameter names are the keys and the values are the dictionaries with the
# prior information) if not specfied here will build from fisher results
priors_dictionary = {}

# Number of points to generate for the Fisher
len_fisher_data = int(1e4)

# Name of the pulsar catalogue
outname = "pulsar_configurations/SKA200p.txt"

# %% [markdown]
# ### Some inputs for the MCMC

# %%
# Whether the MCMC should be rerun
rerun_MCMC = True

# Whether the MCMC data should be regenerated
regenerate_MCMC_data = True

# Whether to generate a data realization or take data at face value
realization = False

# Number of burnin steps for the MCMC
burnin_steps_default = 100

# Maximum number of iterations to get R close to 1
i_max_default = 100

# Accepted value for the Gellman-Rubin convergence criterion
R_convergence_default = 1e-1

# Criterion to be used for the convergence of the MCMC chains
R_criterion_default = "mean_squared"

# Number of MCMC steps in each iteration
MCMC_iteration_steps_default = 300

# Path to the MCMC_data
path_to_MCMC_data = "generated_data/MCMC_data_Pl+SIGW_200p.npz"

# Path to the MCMC chains
path_to_MCMC_chains = "generated_chains/MCMC_chains_Pl+SIGW_200p.npz"

# %% [markdown]
# ### Set the inputs for the Fisher and MCMC analysis

# %%
# Get the signal model
signal_model = get_signal_model(signal_label)

# Dictionary with the kwargs to generete the pulsar catalogs
generate_catalog_kwargs = {
    "n_pulsars": n_pulsars,
    "save_catalog": True,
    **which_experiment,
}

# Dictionary with the kwargs to generate noise and orf tensors
get_tensors_kwargs = {
    "add_curn": False,
    "regenerate_catalog": True,
    "path_to_pulsar_catalog": outname,
}

# Dictionary with the kwargs for the Fisher matrix
fisher_kwargs = {
    "T_obs_yrs": T_obs_yrs,
    "n_frequencies": n_frequencies,
    "signal_model": signal_model,
    "signal_parameters": signal_parameters,
}

# Dictionary with the kwargs for the MCMC
MCMC_kwargs = {
    "regenerate_MCMC_data": regenerate_MCMC_data,
    "realization": realization,
    "path_to_MCMC_data": path_to_MCMC_data,
    "path_to_MCMC_chains": path_to_MCMC_chains,
    "i_max": i_max_default,
    "R_convergence": R_convergence_default,
    "R_criterion": R_criterion_default,
    "burnin_steps": burnin_steps_default,
    "MCMC_iteration_steps": MCMC_iteration_steps_default,
}

# %% [markdown]
# ### Prepare the model to scan over

# %%
if "regenerate_catalog" in get_tensors_kwargs.keys():
    if get_tensors_kwargs["regenerate_catalog"]:
        rerun_MCMC = True

(
    frequency,
    signal_value,
    HD_functions_IJ,
    HD_coeffs,
    effective_noise,
    SNR,
    fisher,
) = compute_fisher(
    **fisher_kwargs,
    get_tensors_kwargs=get_tensors_kwargs,
    generate_catalog_kwargs=generate_catalog_kwargs,
)

covariance = ut.compute_inverse(fisher)
fisher_data = np.random.multivariate_normal(
    signal_parameters, covariance, size=len_fisher_data
)
errors = np.sqrt(np.diag(covariance))
print("Fisher errors", errors)

fisher_ranges = np.vstack(
    (signal_parameters - 5 * errors, signal_parameters + 5 * errors)
)

get_tensors_kwargs["regenerate_catalog"] = False
# Out:
# Fisher errors [0.01655999 0.07620764 0.06124139 0.06356644 0.05247935]

# %%
to_keep = []

for i in tqdm.tqdm(range(len(fisher_data))):

    PBH_abundance = signal_model.get_PBH_abundance(fisher_data[i])

    if PBH_abundance > 1 or np.isnan(PBH_abundance):
        to_keep.append(False)

    else:
        to_keep.append(True)

fisher_reject = fisher_data[to_keep]
# Out:
#   2%|▏         | 179/10000 [00:00<00:22, 444.68it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[38], line 7
#       3 for i in tqdm.tqdm(range(len(fisher_data))):
#       5     PBH_abundance = signal_model.get_PBH_abundance(fisher_data[i])
# ----> 7     if PBH_abundance > 1 or np.isnan(PBH_abundance):
#       8         to_keep.append(False)
#      10     else:
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/jax/_src/array.py:293, in ArrayImpl.__bool__(self)
#     291 def __bool__(self):
#     292   core.check_bool_conversion(self)
# --> 293   return bool(self._value)
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/jax/_src/profiler.py:333, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     330 @wraps(func)
#     331 def wrapper(*args, **kwargs):
#     332   with TraceAnnotation(name, **decorator_kwargs):
# --> 333     return func(*args, **kwargs)
#     334   return wrapper
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/jax/_src/array.py:627, in ArrayImpl._value(self)
#     625 if self._npy_value is None:
#     626   if self.is_fully_replicated:
# --> 627     self._npy_value = self._single_device_array_to_np_array()
#     628     self._npy_value.flags.writeable = False
#     629     return cast(np.ndarray, self._npy_value)
#
# KeyboardInterrupt:

# %%
mean = np.mean(fisher_reject, axis=0)
std = np.std(fisher_reject, axis=0)

# %%
parameter_names = signal_model.parameter_names

ndims = len(parameter_names)
nwalkers = max(2 * ndims, 5)
initial = np.empty((nwalkers, ndims))

mins = np.array([s * 0.99 if s > 0 else s * 1.01 for s in signal_parameters])
maxs = np.array([s * 1.01 if s > 0 else s * 0.99 for s in signal_parameters])

i = 0
while i < nwalkers:
    new = np.random.uniform(mins, maxs)
    
    PBH_abundance = signal_model.get_PBH_abundance(new)

    if PBH_abundance > 1 or np.isnan(PBH_abundance):
        pass  # Do nothing
    else:
        initial[i] = new
        i += 1

# %%
# If the priors dictionary is empty, build it from the Fisher results
if not priors_dictionary:

    mins = np.array([s * 0.9 if s > 0 else s * 1.1 for s in signal_parameters])
    maxs = np.array([s * 1.1 if s > 0 else s * 0.9 for s in signal_parameters])

    parameter_names = signal_model.parameter_names
    diffs = np.abs(np.diff(fisher_ranges, axis=0).squeeze())

    for i in range(len(parameter_names)):

        if i < 2:
            priors_dictionary[parameter_names[i]] = {
                "uniform": {"loc": fisher_ranges[0, i], "scale": diffs[i]}
            }

        else:
            priors_dictionary[parameter_names[i]] = {
                "uniform": {"loc": -10.0, "scale": 10.0}
            }

priors_dictionary["log_amplitude_scalar"] = {
    "uniform": {"loc": -3.0, "scale": 2.0}
}
priors_dictionary["log_width"] = {"uniform": {"loc": -1.8, "scale": 2.6}}
priors_dictionary["log_pivot"] = {"uniform": {"loc": -9., "scale": 2.}}

priors = Priors(
    priors_dictionary, get_PBH_abundance=signal_model.get_PBH_abundance, 
)

# %%
try:
    if rerun_MCMC:
        raise FileNotFoundError("Flag forces MCMC chains regeneration")

    MCMC_results = np.load(path_to_MCMC_chains)
    MCMC_data = MCMC_results["samples"]
    pdfs = MCMC_results["pdfs"]

except FileNotFoundError:
    MCMC_data, pdfs = run_MCMC(
        priors,
        initial=initial,
        **fisher_kwargs,
        **MCMC_kwargs,
        get_tensors_kwargs=get_tensors_kwargs,
    )
# Out:
# Regenerating MCMC data
# - Data will use the expectation value
#
# Initial run
#   0%|          | 0/100 [00:00<?, ?it/s]/home/mauro/.pyenv/versions/3.12.4/lib/python3.12/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# 100%|██████████| 100/100 [00:56<00:00,  1.78it/s]
# Burn-in dropped, here starts the proper run
# 100%|██████████| 300/300 [03:22<00:00,  1.48it/s]
# At this step R = 66.1973
# 100%|██████████| 300/300 [03:20<00:00,  1.50it/s]
# At this step R = 67.6183
#  44%|████▎     | 131/300 [01:26<02:05,  1.35it/s]Traceback (most recent call last):
#   File "/tmp/ipykernel_164329/797928998.py", line 3, in <module>
#     raise FileNotFoundError("Flag forces MCMC chains regeneration")
# FileNotFoundError: Flag forces MCMC chains regeneration
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mauro/.pyenv/versions/3.12.4/lib/python3.12/site-packages/emcee/ensemble.py", line 640, in __call__
#     return self.f(x, *self.args, **self.kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mauro/Media/HD1/My_projects/PTA_forecasts/code/fastpta_models/fastPTA/MCMC_code.py", line 352, in log_posterior
#     if not jnp.isfinite(lp):
#            ^^^^^^^^^^^^^^^^
#   File "/home/mauro/.pyenv/versions/3.12.4/lib/python3.12/site-packages/jax/_src/array.py", line 293, in __bool__
#     return bool(self._value)
#                 ^^^^^^^^^^^
#   File "/home/mauro/.pyenv/versions/3.12.4/lib/python3.12/site-packages/jax/_src/profiler.py", line 333, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mauro/.pyenv/versions/3.12.4/lib/python3.12/site-packages/jax/_src/array.py", line 627, in _value
#     self._npy_value = self._single_device_array_to_np_array()
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#  44%|████▎     | 131/300 [01:26<01:51,  1.52it/s]
# emcee: Exception while calling your likelihood function:
#   params: [-7.2127394   1.8291808  -1.75388935 -0.18919195 -8.12138234]
#   args: [Array([3.16880878e-09, 6.33761756e-09, 9.50642634e-09, 1.26752351e-08,
#        1.58440439e-08, 1.90128527e-08, 2.21816615e-08, 2.53504703e-08,
#        2.85192790e-08, 3.16880878e-08, 3.48568966e-08, 3.80257054e-08,
#        4.11945142e-08, 4.43633229e-08, 4.75321317e-08, 5.07009405e-08,
#        5.38697493e-08, 5.70385581e-08, 6.02073668e-08, 6.33761756e-08,
#        6.65449844e-08, 6.97137932e-08, 7.28826020e-08, 7.60514108e-08,
#        7.92202195e-08, 8.23890283e-08, 8.55578371e-08, 8.87266459e-08,
#        9.18954547e-08, 9.50642634e-08], dtype=float64, weak_type=True), <fastPTA.signals.Signal_model object at 0x7be419d8b920>, Array([[[ 0.4891426 , -0.02223717,  0.02765662, ...,  0.0669196 ,
#          -0.04243413,  0.05342267],
#         [-0.02223717,  0.56484644,  0.19322388, ..., -0.07917785,
#          -0.05506931, -0.01595297],
#         [ 0.02765662,  0.19322388,  0.47668144, ..., -0.07421269,
#          -0.06840432,  0.0638899 ],
#         ...,
#         [ 0.0669196 , -0.07917785, -0.07421269, ...,  0.51371156,
#          -0.04217907, -0.06219757],
#         [-0.04243413, -0.05506931, -0.06840432, ..., -0.04217907,
#           0.61337306, -0.07394613],
#         [ 0.05342267, -0.01595297,  0.0638899 , ..., -0.06219757,
#          -0.07394613,  0.49252684]],
#
#        [[ 0.96782445, -0.04146414,  0.05531253, ...,  0.12974487,
#          -0.07652167,  0.10540049],
#         [-0.04146414,  0.99255756,  0.36418107, ..., -0.14466805,
#          -0.093586  , -0.02966133],
#         [ 0.05531253,  0.36418107,  0.96364281, ..., -0.14543816,
#          -0.12468553,  0.12741265],
#         ...,
#         [ 0.12974487, -0.14466805, -0.14543816, ...,  0.97595973,
#          -0.07453186, -0.12024476],
#         [-0.07652167, -0.093586  , -0.12468553, ..., -0.07453186,
#           1.00809617, -0.13296598],
#         [ 0.10540049, -0.02966133,  0.12741265, ..., -0.12024476,
#          -0.13296598,  0.96895319]],
#
#        [[ 0.98173549, -0.04199191,  0.05612527, ...,  0.13153367,
#          -0.07743125,  0.10690659],
#         [-0.04199191,  1.00356072,  0.36893285, ..., -0.14642472,
#          -0.09454482, -0.03003638],
#         [ 0.05612527,  0.36893285,  0.97811079, ..., -0.14748986,
#          -0.12620743,  0.12927408],
#         ...,
#         [ 0.13153367, -0.14642472, -0.14748986, ...,  0.98884332,
#          -0.07537418, -0.12189247],
#         [-0.07743125, -0.09454482, -0.12620743, ..., -0.07537418,
#           1.01757793, -0.13453531],
#         [ 0.10690659, -0.03003638,  0.12927408, ..., -0.12189247,
#          -0.13453531,  0.9827173 ]],
#
#        ...,
#
#        [[ 0.98309542, -0.04204342,  0.05620475, ...,  0.13170843,
#          -0.07751995,  0.10705381],
#         [-0.04204342,  1.00463255,  0.36939679, ..., -0.14659604,
#          -0.09463813, -0.03007298],
#         [ 0.05620475,  0.36939679,  0.97952615, ..., -0.14769038,
#          -0.12635591,  0.12945609],
#         ...,
#         [ 0.13170843, -0.14659604, -0.14769038, ...,  0.99010121,
#          -0.07545627, -0.12205343],
#         [-0.07751995, -0.09463813, -0.12635591, ..., -0.07545627,
#           1.01849988, -0.13468834],
#         [ 0.10705381, -0.03007298,  0.12945609, ..., -0.12205343,
#          -0.13468834,  0.98406262]],
#
#        [[ 0.98309542, -0.04204342,  0.05620475, ...,  0.13170843,
#          -0.07751995,  0.10705381],
#         [-0.04204342,  1.00463255,  0.36939679, ..., -0.14659604,
#          -0.09463813, -0.03007298],
#         [ 0.05620475,  0.36939679,  0.97952615, ..., -0.14769038,
#          -0.12635591,  0.12945609],
#         ...,
#         [ 0.13170843, -0.14659604, -0.14769038, ...,  0.99010121,
#          -0.07545627, -0.12205343],
#         [-0.07751995, -0.09463813, -0.12635591, ..., -0.07545627,
#           1.01849988, -0.13468834],
#         [ 0.10705381, -0.03007298,  0.12945609, ..., -0.12205343,
#          -0.13468834,  0.98406262]],
#
#        [[ 0.98309542, -0.04204342,  0.05620475, ...,  0.13170843,
#          -0.07751995,  0.10705381],
#         [-0.04204342,  1.00463255,  0.36939679, ..., -0.14659604,
#          -0.09463813, -0.03007298],
#         [ 0.05620475,  0.36939679,  0.97952615, ..., -0.14769038,
#          -0.12635591,  0.12945609],
#         ...,
#         [ 0.13170843, -0.14659604, -0.14769038, ...,  0.99010121,
#          -0.07545627, -0.12205343],
#         [-0.07751995, -0.09463813, -0.12635591, ..., -0.07545627,
#           1.01849988, -0.13468834],
#         [ 0.10705381, -0.03007298,  0.12945609, ..., -0.12205343,
#          -0.13468834,  0.98406262]]], dtype=float64), Array([[[7.68927815e-11, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 1.36979963e-13, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 1.79225161e-12, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         ...,
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          1.09479555e-13, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 1.52378902e-07, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 3.85224535e-11]],
#
#        [[1.96262746e-09, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 4.38335882e-12, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 3.50925946e-11, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         ...,
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          3.50334577e-12, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 4.44616178e-07, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 7.61998211e-10]],
#
#        [[1.30598539e-08, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 3.32861310e-11, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 2.09896946e-10, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#
#          -8.33421602e-08, -5.38032703e-08, -1.70969612e-08],
#         [ 3.19532888e-08,  2.10007897e-07,  1.12839517e-05, ...,
#          -8.39643063e-08, -7.18353256e-08,  7.35978300e-08],
#         ...,
#         [ 7.48783197e-08, -8.33421602e-08, -8.39643063e-08, ...,
#           3.22324133e-06, -4.28980764e-08, -6.93892992e-08],
#         [-4.40713143e-08, -5.38032703e-08, -7.18353256e-08, ...,
#          -4.28980764e-08,  8.31305134e-05, -7.65724462e-08],
#         [ 6.08617787e-08, -1.70969612e-08,  7.35978300e-08, ...,
#          -6.93892992e-08, -7.65724462e-08,  2.20526044e-04]]],      dtype=float64), <fastPTA.priors.Priors object at 0x7be3d4dad340>]
#   kwargs: {}
#   exception:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[32], line 3
#       2 if rerun_MCMC:
# ----> 3     raise FileNotFoundError("Flag forces MCMC chains regeneration")
#       5 MCMC_results = np.load(path_to_MCMC_chains)
#
# FileNotFoundError: Flag forces MCMC chains regeneration
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 10
#       7     pdfs = MCMC_results["pdfs"]
#       9 except FileNotFoundError:
# ---> 10     MCMC_data, pdfs = run_MCMC(
#      11         priors,
#      12         initial=initial,
#      13         **fisher_kwargs,
#      14         **MCMC_kwargs,
#      15         get_tensors_kwargs=get_tensors_kwargs,
#      16     )
#
# File ~/Media/HD1/My_projects/PTA_forecasts/code/fastpta_models/fastPTA/MCMC_code.py:512, in run_MCMC(priors, T_obs_yrs, n_frequencies, signal_model, signal_parameters, initial, regenerate_MCMC_data, realization, save_MCMC_data, path_to_MCMC_data, i_max, R_convergence, R_criterion, burnin_steps, MCMC_iteration_steps, path_to_MCMC_chains, get_tensors_kwargs, generate_catalog_kwargs)
#     509 # Run until convergence or until reached maximum number of iterations
#     510 while np.abs(R - 1) > R_convergence and i < i_max:
#     511     # Run this iteration
# --> 512     state = sampler.run_mcmc(state, MCMC_iteration_steps, progress=True)
#     514     # Get Gelman-Rubin at this step
#     515     R_array = ut.get_R(sampler.get_chain())
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/emcee/ensemble.py:450, in EnsembleSampler.run_mcmc(self, initial_state, nsteps, **kwargs)
#     447     initial_state = self._previous_state
#     449 results = None
# --> 450 for results in self.sample(initial_state, iterations=nsteps, **kwargs):
#     451     pass
#     453 # Store so that the ``initial_state=None`` case will work
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/emcee/ensemble.py:409, in EnsembleSampler.sample(self, initial_state, log_prob0, rstate0, blobs0, iterations, tune, skip_initial_state_check, thin_by, thin, store, progress, progress_kwargs)
#     406 move = self._random.choice(self._moves, p=self._weights)
#     408 # Propose
# --> 409 state, accepted = move.propose(model, state)
#     410 state.random_state = self.random_state
#     412 if tune:
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/emcee/moves/red_blue.py:93, in RedBlueMove.propose(self, model, state)
#      90 q, factors = self.get_proposal(s, c, model.random)
#      92 # Compute the lnprobs of the proposed position.
# ---> 93 new_log_probs, new_blobs = model.compute_log_prob_fn(q)
#      95 # Loop over the walkers and update them accordingly.
#      96 for i, (j, f, nlp) in enumerate(
#      97     zip(all_inds[S1], factors, new_log_probs)
#      98 ):
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/emcee/ensemble.py:496, in EnsembleSampler.compute_log_prob(self, coords)
#     494     else:
#     495         map_func = map
# --> 496     results = list(map_func(self.log_prob_fn, p))
#     498 try:
#     499     # perhaps log_prob_fn returns blobs?
#     500
#    (...)
#     504     # l is a length-1 array, np.array([1.234]). In that case blob
#     505     # will become an empty list.
#     506     blob = [l[1:] for l in results if len(l) > 1]
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/emcee/ensemble.py:640, in _FunctionWrapper.__call__(self, x)
#     638 def __call__(self, x):
#     639     try:
# --> 640         return self.f(x, *self.args, **self.kwargs)
#     641     except:  # pragma: no cover
#     642         import traceback
#
# File ~/Media/HD1/My_projects/PTA_forecasts/code/fastpta_models/fastPTA/MCMC_code.py:352, in log_posterior(signal_parameters, frequency, signal_model, response_IJ, strain_omega, data, priors)
#     319 """
#     320 Compute the logarithm of the posterior probability summing log likelihood
#     321 and prior.
#    (...)
#     345
#     346 """
#     348 lp = priors.evaluate_log_priors(
#     349     dict(zip(signal_model.parameter_names, signal_parameters))
#     350 )
# --> 352 if not jnp.isfinite(lp):
#     353     return -jnp.inf
#     355 signal_value = signal_model.template(frequency, signal_parameters)
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/jax/_src/array.py:293, in ArrayImpl.__bool__(self)
#     291 def __bool__(self):
#     292   core.check_bool_conversion(self)
# --> 293   return bool(self._value)
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/jax/_src/profiler.py:333, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     330 @wraps(func)
#     331 def wrapper(*args, **kwargs):
#     332   with TraceAnnotation(name, **decorator_kwargs):
# --> 333     return func(*args, **kwargs)
#     334   return wrapper
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/jax/_src/array.py:627, in ArrayImpl._value(self)
#     625 if self._npy_value is None:
#     626   if self.is_fully_replicated:
# --> 627     self._npy_value = self._single_device_array_to_np_array()
#     628     self._npy_value.flags.writeable = False
#     629     return cast(np.ndarray, self._npy_value)
#
# KeyboardInterrupt:

# %%
# Set the labels for the signal parameters
if not parameter_labels:
    parameter_labels = signal_model.parameter_labels

# Prepare input for the plotting function
datasets = [fisher_data, fisher_reject, MCMC_data]
weights = [
    np.ones(len_fisher_data),
    np.ones(len(fisher_reject)),
    np.ones(MCMC_data.shape[0]),  # type: ignore
]
smooth = [1.0, 1.0, 1.0]
ranges = np.array(fisher_ranges.T)
colors = [
    pf.my_colormap["red"],
    pf.my_colormap["blue"],
    pf.my_colormap["green"],
]

# Do the corner plot
pf.plot_corner(
    datasets,
    colors=colors,
    truths=signal_parameters,
    chain_labels=["Fisher", "Fisher reject", "MCMC"],
    weights=weights,
    smooth=smooth,
    labels=parameter_labels,
    # range=ranges,
    truth_color="black",
)
